# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Nashville Housing.csv')
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress            SaleDate SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE       April 9, 2013    240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE       June 10, 2014    366000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE  September 26, 2016    435000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE    January 29, 2016    255000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE    October 10, 2014    278000
# ...                                    ...                 ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE        May 27, 2015    157500
# 56473  1423  WINDING CREEK DR, NOLENSVILLE       March 2, 2015    145000
# 56474    1804 GRACE POINT  LN, NOLENSVILLE     August 16, 2016    234611
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE   September 7, 2016     93844
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE   September 7, 2016     93844
#
#          LegalReference SoldAsVacant                           OwnerName  \
# 0      20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1      20140619-0053768           No             BONER, CHARLES & LESLIE
# 2      20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3      20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4      20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
# ...                 ...          ...                                 ...
# 56472  20150608-0053286           No                                 NaN
# 56473  20150304-0019013           No                                 NaN
# 56474  20160819-0087214          Yes                                 NaN
# 56475  20160919-0098411          Yes                                 NaN
# 56476  20160919-0098411          Yes                                 NaN
#
#                                  OwnerAddress  Acreage  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN      3.5
# 2      1864  FOX CHASE DR, GOODLETTSVILLE, TN      2.9
# 3      1853  FOX CHASE DR, GOODLETTSVILLE, TN      2.6
# 4      1829  FOX CHASE DR, GOODLETTSVILLE, TN      2.0
# ...                                       ...      ...
# 56472                                     NaN      NaN
# 56473                                     NaN      NaN
# 56474                                     NaN      NaN
# 56475                                     NaN      NaN
# 56476                                     NaN      NaN
#
#                      TaxDistrict  LandValue  BuildingValue  TotalValue  \
# 0      GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0
# 1      GENERAL SERVICES DISTRICT    50000.0       264100.0    319000.0
# 2      GENERAL SERVICES DISTRICT    50000.0       216200.0    298000.0
# 3      GENERAL SERVICES DISTRICT    50000.0       147300.0    197300.0
# 4      GENERAL SERVICES DISTRICT    50000.0       152300.0    202300.0
# ...                          ...        ...            ...         ...
# 56472                        NaN        NaN            NaN         NaN
# 56473                        NaN        NaN            NaN         NaN
# 56474                        NaN        NaN            NaN         NaN
# 56475                        NaN        NaN            NaN         NaN
# 56476                        NaN        NaN            NaN         NaN
#
#        YearBuilt  Bedrooms  FullBath  HalfBath
# 0         1986.0       3.0       3.0       0.0
# 1         1998.0       3.0       3.0       2.0
# 2         1987.0       4.0       3.0       0.0
# 3         1985.0       3.0       3.0       0.0
# 4         1984.0       4.0       3.0       0.0
# ...          ...       ...       ...       ...
# 56472        NaN       NaN       NaN       NaN
# 56473        NaN       NaN       NaN       NaN
# 56474        NaN       NaN       NaN       NaN
# 56475        NaN       NaN       NaN       NaN
# 56476        NaN       NaN       NaN       NaN
#
# [56477 rows x 19 columns]

# %%
df=df.drop(["ParcelID","LandUse","PropertyAddress","SaleDate","LegalReference","OwnerName","OwnerAddress","TaxDistrict"], axis=1)
df
# Out:
#        UniqueID  SalePrice SoldAsVacant  Acreage  LandValue  BuildingValue  \
# 0           2045    240000           No      2.3    50000.0       168200.0
# 1          16918    366000           No      3.5    50000.0       264100.0
# 2          54582    435000           No      2.9    50000.0       216200.0
# 3          43070    255000           No      2.6    50000.0       147300.0
# 4          22714    278000           No      2.0    50000.0       152300.0
# ...          ...       ...          ...      ...        ...            ...
# 56472      30469    157500           No      NaN        NaN            NaN
# 56473      27707    145000           No      NaN        NaN            NaN
# 56474      52709    234611          Yes      NaN        NaN            NaN
# 56475      54042     93844          Yes      NaN        NaN            NaN
# 56476      54043     93844          Yes      NaN        NaN            NaN
#
#        TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 0        235700.0     1986.0       3.0       3.0       0.0
# 1        319000.0     1998.0       3.0       3.0       2.0
# 2        298000.0     1987.0       4.0       3.0       0.0
# 3        197300.0     1985.0       3.0       3.0       0.0
# 4        202300.0     1984.0       4.0       3.0       0.0
# ...           ...        ...       ...       ...       ...
# 56472         NaN        NaN       NaN       NaN       NaN
# 56473         NaN        NaN       NaN       NaN       NaN
# 56474         NaN        NaN       NaN       NaN       NaN
# 56475         NaN        NaN       NaN       NaN       NaN
# 56476         NaN        NaN       NaN       NaN       NaN
#
# [56477 rows x 11 columns]

# %%
df["SoldAsVacant"] = df["SoldAsVacant"].map(
    {"No": "0","Yes": "1","N": "0", "Y": "1"},
    #na_action=None,
)

# %%
df['SoldAsVacant'] = df['SoldAsVacant'].astype(int) # convierto la columna SoldAsVacant en entero

# %%
df["SoldAsVacant"].value_counts()
# Out:
# SoldAsVacant
# 0    51802
# 1     4675
# Name: count, dtype: int64

# %%
#df['SalePrice'] = df['SalePrice'].apply(lambda x: x.replace(',','.'))

# %%
df['SalePrice'] = df['SalePrice'].str.replace('$','') #reemplazo el caracter $ por un espacio vacio
#df["SalePrice"] = df["SalePrice"].apply(lambda x: x.replace('$',''))

# %%
#df['SalePrice'] = df['SalePrice'].apply(lambda x: x.replace(',','.'))

# %%
df['SalePrice'] = df['SalePrice'].str.strip() #elimino los espacios en blanco al pricipio y al final de cada valor

# %%
#df['SalePrice'] = df['SalePrice'].astype(float)
df['SalePrice'] = df['SalePrice'].str.replace(',', '', regex=False).astype(float) #reemplaza la , por espacio en blanco y convierte
# la columna SalePrice en flotante

# %%
df=df.fillna(df.median()) #completo los valores NA con la mediana
df
# Out:
#        UniqueID   SalePrice  SoldAsVacant  Acreage  LandValue  BuildingValue  \
# 0           2045   240000.0             0     2.30    50000.0       168200.0
# 1          16918   366000.0             0     3.50    50000.0       264100.0
# 2          54582   435000.0             0     2.90    50000.0       216200.0
# 3          43070   255000.0             0     2.60    50000.0       147300.0
# 4          22714   278000.0             0     2.00    50000.0       152300.0
# ...          ...        ...           ...      ...        ...            ...
# 56472      30469   157500.0             0     0.27    28800.0       111400.0
# 56473      27707   145000.0             0     0.27    28800.0       111400.0
# 56474      52709   234611.0             1     0.27    28800.0       111400.0
# 56475      54042    93844.0             1     0.27    28800.0       111400.0
# 56476      54043    93844.0             1     0.27    28800.0       111400.0
#
#        TotalValue  YearBuilt  Bedrooms  FullBath  HalfBath
# 0        235700.0     1986.0       3.0       3.0       0.0
# 1        319000.0     1998.0       3.0       3.0       2.0
# 2        298000.0     1987.0       4.0       3.0       0.0
# 3        197300.0     1985.0       3.0       3.0       0.0
# 4        202300.0     1984.0       4.0       3.0       0.0
# ...           ...        ...       ...       ...       ...
# 56472    148500.0     1960.0       3.0       2.0       0.0
# 56473    148500.0     1960.0       3.0       2.0       0.0
# 56474    148500.0     1960.0       3.0       2.0       0.0
# 56475    148500.0     1960.0       3.0       2.0       0.0
# 56476    148500.0     1960.0       3.0       2.0       0.0
#
# [56477 rows x 11 columns]

# %%
#Separamos en X e y
X = df.drop(["SoldAsVacant"], axis=1)
y = df["SoldAsVacant"]

# %%
X
# Out:
#        UniqueID   SalePrice  Acreage  LandValue  BuildingValue  TotalValue  \
# 0           2045   240000.0     2.30    50000.0       168200.0    235700.0
# 1          16918   366000.0     3.50    50000.0       264100.0    319000.0
# 2          54582   435000.0     2.90    50000.0       216200.0    298000.0
# 3          43070   255000.0     2.60    50000.0       147300.0    197300.0
# 4          22714   278000.0     2.00    50000.0       152300.0    202300.0
# ...          ...        ...      ...        ...            ...         ...
# 56472      30469   157500.0     0.27    28800.0       111400.0    148500.0
# 56473      27707   145000.0     0.27    28800.0       111400.0    148500.0
# 56474      52709   234611.0     0.27    28800.0       111400.0    148500.0
# 56475      54042    93844.0     0.27    28800.0       111400.0    148500.0
# 56476      54043    93844.0     0.27    28800.0       111400.0    148500.0
#
#        YearBuilt  Bedrooms  FullBath  HalfBath
# 0         1986.0       3.0       3.0       0.0
# 1         1998.0       3.0       3.0       2.0
# 2         1987.0       4.0       3.0       0.0
# 3         1985.0       3.0       3.0       0.0
# 4         1984.0       4.0       3.0       0.0
# ...          ...       ...       ...       ...
# 56472     1960.0       3.0       2.0       0.0
# 56473     1960.0       3.0       2.0       0.0
# 56474     1960.0       3.0       2.0       0.0
# 56475     1960.0       3.0       2.0       0.0
# 56476     1960.0       3.0       2.0       0.0
#
# [56477 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
#Separamos en train y test!
X_train, X_test,y_train, y_test = train_test_split(X,y,stratify=y,test_size=0.30,random_state=42)

# %%
#Creamos un arbol de decisión sencillo y lo fiteamos
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_test_pred = clf.predict(X_test)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.953552880075543

# %%
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(16944,))

# %%
y_test
# Out:
# 36178    0
# 26077    0
# 40217    0
# 54881    0
# 25822    1
#         ..
# 5021     1
# 1991     0
# 15885    0
# 21408    0
# 10805    0
# Name: SoldAsVacant, Length: 16944, dtype: int64

# %%
# Classification Report:
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97     15541
#            1       0.71      0.75      0.73      1403
#
#     accuracy                           0.95     16944
#    macro avg       0.84      0.86      0.85     16944
# weighted avg       0.96      0.95      0.95     16944

# %%
print("Feature Selecction:")

for i, feature in enumerate(range(X.shape[1])):
  print(f"feature {feature}: {clf.feature_importances_[i]: .2f}")
# Out:
# Feature Selecction:
# feature 0:  0.43
# feature 1:  0.36
# feature 2:  0.03
# feature 3:  0.02
# feature 4:  0.03
# feature 5:  0.05
# feature 6:  0.03
# feature 7:  0.00
# feature 8:  0.05
# feature 9:  0.00

# %%
# Matriz Confusión:
conf_mat = confusion_matrix(y_test, y_test_pred)
conf_mat
# Out:
# array([[15101,   440],
#        [  347,  1056]])

# %%
# Permite visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=[1,2])
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# RAMDON FOREST CLASSIFICATION

# %%
#Creamos un random forest
model = RandomForestClassifier(random_state=42, n_estimators=100,
                               class_weight="balanced", max_features="log2")

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test,y_pred) #Hubo una mejora pequeña en comparación con el arbol de decisión hecho anteriormente
# Out:
# 0.9641170915958451

# %%
# Classification Report:
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     15541
#            1       0.82      0.73      0.77      1403
#
#     accuracy                           0.96     16944
#    macro avg       0.90      0.86      0.88     16944
# weighted avg       0.96      0.96      0.96     16944

# %%
# Matriz Confusión:
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[15316,   225],
#        [  383,  1020]])

# %%
# Permite visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=[1,2])
disp.plot(cmap=plt.cm.Blues)

# %%
print("Feature Selecction:")

for i, feature in enumerate(range(X.shape[1])):
  print(f"feature {feature}: {model.feature_importances_[i]: .2f}")
# Out:
# Feature Selecction:
# feature 0:  0.29
# feature 1:  0.40
# feature 2:  0.02
# feature 3:  0.03
# feature 4:  0.07
# feature 5:  0.05
# feature 6:  0.11
# feature 7:  0.01
# feature 8:  0.02
# feature 9:  0.00

# %% [markdown]
# MODELO SVC

# %%
# Creamos un modelo SVC
modelo = SVC(C=0.1,kernel='rbf',random_state=42)

# %%
modelo.fit(X_train,y_train)
# Out:
# SVC(C=0.1, random_state=42)

# %%
y_pred = modelo.predict(X_test)

# %%
accuracy_score(y_test,y_pred) # Podemos ver que hubo una disminución de eficiencia en comparación con los 2 modelos anteriores
# Out:
# 0.9171978281397545

# %%
# Classification Report:
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     15541
#            1       0.00      0.00      0.00      1403
#
#     accuracy                           0.92     16944
#    macro avg       0.46      0.50      0.48     16944
# weighted avg       0.84      0.92      0.88     16944

# %%
# Matriz Confusión:
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[15541,     0],
#        [ 1403,     0]])

# %%
# Permite visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=[1,2])
disp.plot(cmap=plt.cm.Blues)

# %% [markdown]
# MODELO REGRESIÓN LOGICA

# %%
# Creamos un modelo de LR
model_lr = LogisticRegression()

# %%
model_lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model_lr.predict(X_test)

# %%
accuracy_score(y_test,y_pred)  # Hubo una disminición demasiado pequeña en comparación con el modelo SVC
# Out:
# 0.9166076487252125

# %%
# Classification Report:
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     15541
#            1       0.08      0.00      0.00      1403
#
#     accuracy                           0.92     16944
#    macro avg       0.50      0.50      0.48     16944
# weighted avg       0.85      0.92      0.88     16944

# %%
# Matriz Confusión:
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[15530,    11],
#        [ 1402,     1]])

# %%
# Permite visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=[1,2])
disp.plot(cmap=plt.cm.CMRmap)

# %% [markdown]
# MODELO KNN

# %%
# Creamos el modelo KNN
modelo = KNeighborsClassifier()

# %%
modelo.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = modelo.predict(X_test)

# %%
accuracy_score(y_test,y_pred) # Hubo un pequeño aumento de eficiencia en comparación con el modelo LR y el modelo SVC,pero
#se encuentra por debajo de los modelos de Ramdon forest y arbol de decición
# Out:
# 0.9394475920679887

# %%
# Classification Report:
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     15541
#            1       0.65      0.59      0.62      1403
#
#     accuracy                           0.94     16944
#    macro avg       0.81      0.78      0.79     16944
# weighted avg       0.94      0.94      0.94     16944

# %%
# Matriz Confusión:
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[15089,   452],
#        [  574,   829]])

# %%
# Permite visualizar la matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=[1,2])
disp.plot(cmap=plt.cm.CMRmap)
