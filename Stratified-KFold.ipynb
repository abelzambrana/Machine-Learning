# %% [markdown]
# STRATIFIED- K FOLD

# %%
import numpy as np
from numpy import std
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('Mall_Customer.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df_Genre= df["Genre"]
df=df.drop(["CustomerID", "Genre"], axis=1)
df_Genre
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: object

# %%
df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     200 non-null    int64
#  1   Annual Income (k$)      200 non-null    int64
#  2   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3)
# memory usage: 4.8 KB

# %%
df_Genre = df_Genre.map(
    {"Male": "M","Female": "F"},
    #na_action=None,
)
df_Genre
# Out:
# 0      M
# 1      M
# 2      F
# 3      F
# 4      F
#       ..
# 195    F
# 196    F
# 197    M
# 198    M
# 199    M
# Name: Genre, Length: 200, dtype: object

# %%
dataframe = pd.concat([df, df_Genre], axis=1)
dataframe
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100) Genre
# 0     19                  15                      39     M
# 1     21                  15                      81     M
# 2     20                  16                       6     F
# 3     23                  16                      77     F
# 4     31                  17                      40     F
# ..   ...                 ...                     ...   ...
# 195   35                 120                      79     F
# 196   45                 126                      28     F
# 197   32                 126                      74     M
# 198   32                 137                      18     M
# 199   30                 137                      83     M
#
# [200 rows x 4 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     200 non-null    int64
#  1   Annual Income (k$)      200 non-null    int64
#  2   Spending Score (1-100)  200 non-null    int64
#  3   Genre                   200 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
# Tamaño
dataframe.shape
# Out:
# (200, 4)

# %%
# Nulos:
dataframe.isnull().sum()
# Out:
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# Genre                     0
# dtype: int64

# %%
# Separar en X y y
X = df.to_numpy()
X
# Out:
# array([[ 19,  15,  39],
#        [ 21,  15,  81],
#        [ 20,  16,   6],
#        [ 23,  16,  77],
#        [ 31,  17,  40],
#        [ 22,  17,  76],
#        [ 35,  18,   6],
#        [ 23,  18,  94],
#        [ 64,  19,   3],
#        [ 30,  19,  72],
#        [ 67,  19,  14],
#        [ 35,  19,  99],
#        [ 58,  20,  15],
#        [ 24,  20,  77],
#        [ 37,  20,  13],
#        [ 22,  20,  79],
#        [ 35,  21,  35],
#        [ 20,  21,  66],
#        [ 52,  23,  29],
#        [ 35,  23,  98],
#        [ 35,  24,  35],
#        [ 25,  24,  73],
#        [ 46,  25,   5],
#        [ 31,  25,  73],
#        [ 54,  28,  14],
#        [ 29,  28,  82],
#        [ 45,  28,  32],
#        [ 35,  28,  61],
#        [ 40,  29,  31],
#        [ 23,  29,  87],
#        [ 60,  30,   4],
#        [ 21,  30,  73],
#        [ 53,  33,   4],
#        [ 18,  33,  92],
#        [ 49,  33,  14],
#        [ 21,  33,  81],
#        [ 42,  34,  17],
#        [ 30,  34,  73],
#        [ 36,  37,  26],
#        [ 20,  37,  75],
#        [ 65,  38,  35],
#        [ 24,  38,  92],
#        [ 56,  79,  35],
#        [ 29,  79,  83],
#        [ 19,  81,   5],
#        [ 31,  81,  93],
#        [ 50,  85,  26],
#        [ 36,  85,  75],
#        [ 42,  86,  20],
#        [ 33,  86,  95],
#        [ 36,  87,  27],
#        [ 32,  87,  63],
#        [ 40,  87,  13],
#        [ 28,  87,  75],
#        [ 36,  87,  10],
#        [ 36,  87,  92],
#        [ 52,  88,  13],
#        [ 30,  88,  86],
#        [ 58,  88,  15],
#        [ 27,  88,  69],
#        [ 59,  93,  14],
#        [ 35,  93,  90],
#        [ 37,  97,  32],
#        [ 32,  97,  86],
#        [ 46,  98,  15],
#        [ 29,  98,  88],
#        [ 41,  99,  39],
#        [ 30,  99,  97],
#        [ 54, 101,  24],
#        [ 28, 101,  68],
#        [ 41, 103,  17],
#        [ 36, 103,  85],
#        [ 34, 103,  23],
#        [ 32, 103,  69],
#        [ 33, 113,   8],
#        [ 38, 113,  91],
#        [ 47, 120,  16],
#        [ 35, 120,  79],
#        [ 45, 126,  28],
#        [ 32, 126,  74],
#        [ 32, 137,  18],
#        [ 30, 137,  83]])

# %%
y = df_Genre.to_numpy()
y
# Out:
# array(['M', 'M', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'F', 'M', 'F', 'F',
#        'F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'F', 'M',
#        'F', 'M', 'F', 'F', 'M', 'F', 'M', 'M', 'F', 'F', 'F', 'F', 'F',
#        'F', 'F', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'M',
#        'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'F', 'F', 'M',
#        'M', 'F', 'F', 'M', 'F', 'M', 'F', 'F', 'F', 'M', 'M', 'F', 'M',
#        'F', 'F', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'F', 'F', 'F', 'F',
#        'M', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'M',
#        'M', 'F', 'F', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'F', 'F',
#        'F', 'F', 'F', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'M', 'M', 'M',
#        'M', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'F',
#        'F', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'F', 'F', 'F', 'F',
#        'M', 'F', 'M', 'F', 'F', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'F',
#        'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'F', 'F',
#        'M', 'F', 'F', 'M', 'F', 'M', 'F', 'F', 'F', 'F', 'M', 'F', 'F',
#        'F', 'F', 'M', 'M', 'M'], dtype=object)

# %%
# crear el procedimiento:
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
skf.get_n_splits(X, y)
# Out:
# 5

# %%
# Modelo vacio
model = RandomForestClassifier(random_state=42,n_estimators=30, criterion="gini",max_depth=4)

# %%
# Lista para guardar accuracy
list_ac=[]
for i in range(0,skf.get_n_splits(X, y)):
  # Calculo de indices
  train, test = list(skf.split(X, y))[i]
  # Separar train y test
  X_train_n, y_train_n, X_test_n, y_test_n= X[train], y[train], X[test],y[test]
  # Ajustar el modelo
  model.fit(X_train_n, y_train_n)
  # Predicciones
  pred= model.predict(X_test_n)
  # Calculo del error
  accuracy= accuracy_score(y_true=y_test_n, y_pred= pred)
  print('Iteracion: ',i+1, ' Accuracy:', accuracy)
  list_ac.append(accuracy)
# Out:
# Iteracion:  1  Accuracy: 0.575
# Iteracion:  2  Accuracy: 0.4
# Iteracion:  3  Accuracy: 0.55
# Iteracion:  4  Accuracy: 0.575
# Iteracion:  5  Accuracy: 0.575

# %%
print('Accuracy promedio:', round(np.mean(list_ac),2))
print('Accuracy std:', round(np.std(list_ac),2))
# Out:
# Accuracy promedio: 0.53
# Accuracy std: 0.07
