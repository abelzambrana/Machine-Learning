# %% [markdown]
# SELECCIÓN DE MODELO- CLASIFICACIÓN

# %%
import numpy as np
from numpy import std
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('Mall_Customer.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df_Genre= df["Genre"]
df=df.drop(["CustomerID", "Genre"], axis=1)
df_Genre
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: object

# %%
df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     200 non-null    int64
#  1   Annual Income (k$)      200 non-null    int64
#  2   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3)
# memory usage: 4.8 KB

# %%
dataframe = pd.concat([df, df_Genre], axis=1)
dataframe
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)   Genre
# 0     19                  15                      39    Male
# 1     21                  15                      81    Male
# 2     20                  16                       6  Female
# 3     23                  16                      77  Female
# 4     31                  17                      40  Female
# ..   ...                 ...                     ...     ...
# 195   35                 120                      79  Female
# 196   45                 126                      28  Female
# 197   32                 126                      74    Male
# 198   32                 137                      18    Male
# 199   30                 137                      83    Male
#
# [200 rows x 4 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     200 non-null    int64
#  1   Annual Income (k$)      200 non-null    int64
#  2   Spending Score (1-100)  200 non-null    int64
#  3   Genre                   200 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
# Nulos:
dataframe.isnull().sum()
# Out:
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# Genre                     0
# dtype: int64

# %%
data = dataframe.drop(['Genre'],axis=1)
data
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
# Target
y1 = dataframe['Genre']
y1
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: object

# %% [markdown]
# PYCARET

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %%
#from pycaret.utils import enable_colab
#enable_colab()

# %%
from pycaret.classification import *

# %%
from sklearn.model_selection import train_test_split

seed = 42
# usamos la rutina train_test_split de Sklearn para dividir los datos en
# training y test (la variable random_state se usa para que siempre obtengamos la
# misma particion aleatoria)
X_train_val, X_test, y_train_val, y_test = train_test_split(data, y1, test_size=0.25, random_state=seed)

# ahora necesitamos partir X_train_val y y_train_val para sacarle el 10% que
# usaremos como validation
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=seed)

# imprimimos por pantalla los tamaños finales
print('=======================================================================================')
print('PARTICIÓN DATASET:')
print('')
print('Instancias de Entrenamiento:')
print('X_train: {}'.format(X_train.shape))
print('y_train: {}'.format(y_train.shape))
print(' ')
print('Instancias de Prueba:')
print('X_test: {}'.format(X_test.shape))
print('y_test: {}'.format(y_test.shape))
print(' ')
print('Instancias de Validación:')
print('X_val: {}'.format(X_val.shape))
print('y_val: {}'.format(y_val.shape))
print('=======================================================================================')
# Out:
# =======================================================================================
# PARTICIÓN DATASET:
#
# Instancias de Entrenamiento:
# X_train: (135, 3)
# y_train: (135,)
#
# Instancias de Prueba:
# X_test: (50, 3)
# y_test: (50,)
#
# Instancias de Validación:
# X_val: (15, 3)
# y_val: (15,)
# =======================================================================================

# %%
#############################################################################
###  Creamos un Data Frame con los datos de Validacion para validar
#############################################################################

data_xval = pd.DataFrame(X_val, columns=data.columns)
data_xval.head()
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 156   37                  78                       1
# 90    68                  59                      55
# 196   45                 126                      28
# 81    38                  54                      55
# 184   41                  99                      39

# %%
data_yval = pd.DataFrame(y_val)
data_yval.head()
# Out:
#       Genre
# 156    Male
# 90   Female
# 196  Female
# 81     Male
# 184  Female

# %%
# Data Set para validar
data_unseen = pd.concat([data_xval,data_yval],axis=1)
data_unseen.head()
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)   Genre
# 156   37                  78                       1    Male
# 90    68                  59                      55  Female
# 196   45                 126                      28  Female
# 81    38                  54                      55    Male
# 184   41                  99                      39  Female

# %%
# Data Set para entrenar en Pycaret:
data_py = pd.concat([X_train,y_train], axis=1)
data_py.head()
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)   Genre
# 10    67                  19                      14    Male
# 13    24                  20                      77  Female
# 28    40                  29                      31  Female
# 144   25                  77                      12    Male
# 149   34                  78                      90    Male

# %%
clf = setup(data=data_py, target='Genre')
# Out:
# <style type="text/css">
# #T_7ea97_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7ea97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ea97_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7ea97_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ea97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ea97_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7ea97_row0_col1" class="data row0 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ea97_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7ea97_row1_col1" class="data row1 col1" >Genre</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ea97_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7ea97_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ea97_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_7ea97_row3_col1" class="data row3 col1" >Female: 0, Male: 1</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ea97_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7ea97_row4_col1" class="data row4 col1" >(135, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ea97_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7ea97_row5_col1" class="data row5 col1" >(135, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ea97_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7ea97_row6_col1" class="data row6 col1" >(94, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ea97_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7ea97_row7_col1" class="data row7 col1" >(41, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ea97_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7ea97_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ea97_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_7ea97_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7ea97_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_7ea97_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7ea97_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_7ea97_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7ea97_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_7ea97_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7ea97_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_7ea97_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7ea97_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_7ea97_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7ea97_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_7ea97_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7ea97_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_7ea97_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7ea97_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_7ea97_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7ea97_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_7ea97_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7ea97_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7ea97_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_7ea97_row19_col1" class="data row19 col1" >bb86</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
## Primer Modelo
model_1 = create_model('knn')
# Out:
# <style type="text/css">
# #T_38eb8_row10_col0, #T_38eb8_row10_col1, #T_38eb8_row10_col2, #T_38eb8_row10_col3, #T_38eb8_row10_col4, #T_38eb8_row10_col5, #T_38eb8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_38eb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38eb8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_38eb8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_38eb8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_38eb8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_38eb8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_38eb8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_38eb8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38eb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38eb8_row0_col0" class="data row0 col0" >0.5000</td>
#       <td id="T_38eb8_row0_col1" class="data row0 col1" >0.6000</td>
#       <td id="T_38eb8_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_38eb8_row0_col3" class="data row0 col3" >0.5000</td>
#       <td id="T_38eb8_row0_col4" class="data row0 col4" >0.4949</td>
#       <td id="T_38eb8_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_38eb8_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38eb8_row1_col0" class="data row1 col0" >0.6000</td>
#       <td id="T_38eb8_row1_col1" class="data row1 col1" >0.6400</td>
#       <td id="T_38eb8_row1_col2" class="data row1 col2" >0.6000</td>
#       <td id="T_38eb8_row1_col3" class="data row1 col3" >0.6000</td>
#       <td id="T_38eb8_row1_col4" class="data row1 col4" >0.6000</td>
#       <td id="T_38eb8_row1_col5" class="data row1 col5" >0.2000</td>
#       <td id="T_38eb8_row1_col6" class="data row1 col6" >0.2000</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38eb8_row2_col0" class="data row2 col0" >0.7000</td>
#       <td id="T_38eb8_row2_col1" class="data row2 col1" >0.6400</td>
#       <td id="T_38eb8_row2_col2" class="data row2 col2" >0.7000</td>
#       <td id="T_38eb8_row2_col3" class="data row2 col3" >0.7083</td>
#       <td id="T_38eb8_row2_col4" class="data row2 col4" >0.6970</td>
#       <td id="T_38eb8_row2_col5" class="data row2 col5" >0.4000</td>
#       <td id="T_38eb8_row2_col6" class="data row2 col6" >0.4082</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38eb8_row3_col0" class="data row3 col0" >0.5000</td>
#       <td id="T_38eb8_row3_col1" class="data row3 col1" >0.4000</td>
#       <td id="T_38eb8_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_38eb8_row3_col3" class="data row3 col3" >0.5000</td>
#       <td id="T_38eb8_row3_col4" class="data row3 col4" >0.4949</td>
#       <td id="T_38eb8_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_38eb8_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38eb8_row4_col0" class="data row4 col0" >0.4444</td>
#       <td id="T_38eb8_row4_col1" class="data row4 col1" >0.5750</td>
#       <td id="T_38eb8_row4_col2" class="data row4 col2" >0.4444</td>
#       <td id="T_38eb8_row4_col3" class="data row4 col3" >0.4556</td>
#       <td id="T_38eb8_row4_col4" class="data row4 col4" >0.4444</td>
#       <td id="T_38eb8_row4_col5" class="data row4 col5" >-0.0976</td>
#       <td id="T_38eb8_row4_col6" class="data row4 col6" >-0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38eb8_row5_col0" class="data row5 col0" >0.5556</td>
#       <td id="T_38eb8_row5_col1" class="data row5 col1" >0.6250</td>
#       <td id="T_38eb8_row5_col2" class="data row5 col2" >0.5556</td>
#       <td id="T_38eb8_row5_col3" class="data row5 col3" >0.5926</td>
#       <td id="T_38eb8_row5_col4" class="data row5 col4" >0.5444</td>
#       <td id="T_38eb8_row5_col5" class="data row5 col5" >0.1429</td>
#       <td id="T_38eb8_row5_col6" class="data row5 col6" >0.1581</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38eb8_row6_col0" class="data row6 col0" >0.6667</td>
#       <td id="T_38eb8_row6_col1" class="data row6 col1" >0.6750</td>
#       <td id="T_38eb8_row6_col2" class="data row6 col2" >0.6667</td>
#       <td id="T_38eb8_row6_col3" class="data row6 col3" >0.6667</td>
#       <td id="T_38eb8_row6_col4" class="data row6 col4" >0.6580</td>
#       <td id="T_38eb8_row6_col5" class="data row6 col5" >0.3077</td>
#       <td id="T_38eb8_row6_col6" class="data row6 col6" >0.3162</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38eb8_row7_col0" class="data row7 col0" >0.5556</td>
#       <td id="T_38eb8_row7_col1" class="data row7 col1" >0.4500</td>
#       <td id="T_38eb8_row7_col2" class="data row7 col2" >0.5556</td>
#       <td id="T_38eb8_row7_col3" class="data row7 col3" >0.5556</td>
#       <td id="T_38eb8_row7_col4" class="data row7 col4" >0.5556</td>
#       <td id="T_38eb8_row7_col5" class="data row7 col5" >0.1000</td>
#       <td id="T_38eb8_row7_col6" class="data row7 col6" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38eb8_row8_col0" class="data row8 col0" >0.6667</td>
#       <td id="T_38eb8_row8_col1" class="data row8 col1" >0.7500</td>
#       <td id="T_38eb8_row8_col2" class="data row8 col2" >0.6667</td>
#       <td id="T_38eb8_row8_col3" class="data row8 col3" >0.6667</td>
#       <td id="T_38eb8_row8_col4" class="data row8 col4" >0.6580</td>
#       <td id="T_38eb8_row8_col5" class="data row8 col5" >0.3077</td>
#       <td id="T_38eb8_row8_col6" class="data row8 col6" >0.3162</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38eb8_row9_col0" class="data row9 col0" >0.5556</td>
#       <td id="T_38eb8_row9_col1" class="data row9 col1" >0.4500</td>
#       <td id="T_38eb8_row9_col2" class="data row9 col2" >0.5556</td>
#       <td id="T_38eb8_row9_col3" class="data row9 col3" >0.5397</td>
#       <td id="T_38eb8_row9_col4" class="data row9 col4" >0.5185</td>
#       <td id="T_38eb8_row9_col5" class="data row9 col5" >0.0526</td>
#       <td id="T_38eb8_row9_col6" class="data row9 col6" >0.0598</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_38eb8_row10_col0" class="data row10 col0" >0.5744</td>
#       <td id="T_38eb8_row10_col1" class="data row10 col1" >0.5805</td>
#       <td id="T_38eb8_row10_col2" class="data row10 col2" >0.5744</td>
#       <td id="T_38eb8_row10_col3" class="data row10 col3" >0.5785</td>
#       <td id="T_38eb8_row10_col4" class="data row10 col4" >0.5666</td>
#       <td id="T_38eb8_row10_col5" class="data row10 col5" >0.1413</td>
#       <td id="T_38eb8_row10_col6" class="data row10 col6" >0.1459</td>
#     </tr>
#     <tr>
#       <th id="T_38eb8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_38eb8_row11_col0" class="data row11 col0" >0.0790</td>
#       <td id="T_38eb8_row11_col1" class="data row11 col1" >0.1067</td>
#       <td id="T_38eb8_row11_col2" class="data row11 col2" >0.0790</td>
#       <td id="T_38eb8_row11_col3" class="data row11 col3" >0.0791</td>
#       <td id="T_38eb8_row11_co

# %%
# Evaluate model:
evaluate_model(model_1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(model_1)

# %%
plot_model(model_1, 'confusion_matrix')

# %%
plot_model(model_1, 'pr')
