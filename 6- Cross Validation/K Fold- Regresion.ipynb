# %% [markdown]
# VALIDACIÓN CRUZADA K FOLD- REGRESION

# %%
# data science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# regression models
from sklearn.linear_model import LinearRegression # for linear regression

# %%
dataset = pd.read_csv('vivienda.csv')
dataset.head()
# Out:
#    UniqueID   Acreage                TaxDistrict  LandValue  BuildingValue  \
# 0       2045      2.3  GENERAL SERVICES DISTRICT    50000.0       168200.0
# 1      16918      3.5  GENERAL SERVICES DISTRICT    50000.0       264100.0
# 2      54582      2.9  GENERAL SERVICES DISTRICT    50000.0       216200.0
# 3      43070      2.6  GENERAL SERVICES DISTRICT    50000.0       147300.0
# 4      22714      2.0  GENERAL SERVICES DISTRICT    50000.0       152300.0
#
#    TotalValue  Bedrooms  FullBath  HalfBath
# 0    235700.0       3.0       3.0       0.0
# 1    319000.0       3.0       3.0       2.0
# 2    298000.0       4.0       3.0       0.0
# 3    197300.0       3.0       3.0       0.0
# 4    202300.0       4.0       3.0       0.0

# %%
#Consultamos el tipo de dato de cada variable
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879 entries, 0 to 5878
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UniqueID       5879 non-null   int64
#  1   Acreage        3764 non-null   float64
#  2   TaxDistrict    3764 non-null   object
#  3   LandValue      3764 non-null   float64
#  4   BuildingValue  3764 non-null   float64
#  5   TotalValue     3764 non-null   float64
#  6   Bedrooms       3543 non-null   float64
#  7   FullBath       3563 non-null   float64
#  8   HalfBath       3527 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 413.5+ KB

# %%
dataset = pd.get_dummies(dataset)
dataset=dataset.fillna(dataset.median())
dataset
# Out:
#       UniqueID   Acreage  LandValue  BuildingValue  TotalValue  Bedrooms  \
# 0          2045     2.30    50000.0       168200.0    235700.0       3.0
# 1         16918     3.50    50000.0       264100.0    319000.0       3.0
# 2         54582     2.90    50000.0       216200.0    298000.0       4.0
# 3         43070     2.60    50000.0       147300.0    197300.0       3.0
# 4         22714     2.00    50000.0       152300.0    202300.0       4.0
# ...         ...      ...        ...            ...         ...       ...
# 5874      39516     0.45    43000.0       157900.0    204700.0       2.0
# 5875      21382     0.46    38700.0       152400.0    191100.0       4.0
# 5876      31288     0.46    38700.0       129900.0    175600.0       2.0
# 5877       9854     0.22    30000.0       103500.0    133500.0       3.0
# 5878      12451     0.39    38700.0       184400.0    229000.0       3.0
#
#       FullBath  HalfBath  TaxDistrict_CITY OF GOODLETTSVILLE  \
# ...

# %%
dataset.isnull().sum()
# Out:
# UniqueID                                 0
# Acreage                                  0
# LandValue                                0
# BuildingValue                            0
# TotalValue                               0
# Bedrooms                                 0
# FullBath                                 0
# HalfBath                                 0
# TaxDistrict_CITY OF GOODLETTSVILLE       0
# TaxDistrict_GENERAL SERVICES DISTRICT    0
# TaxDistrict_URBAN SERVICES DISTRICT      0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879 entries, 0 to 5878
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   UniqueID                               5879 non-null   int64
#  1   Acreage                                5879 non-null   float64
#  2   LandValue                              5879 non-null   float64
#  3   BuildingValue                          5879 non-null   float64
#  4   TotalValue                             5879 non-null   float64
#  5   Bedrooms                               5879 non-null   float64
#  6   FullBath                               5879 non-null   float64
#  7   HalfBath                               5879 non-null   float64
#  8   TaxDistrict_CITY OF GOODLETTSVILLE     5879 non-null   bool
#  9   TaxDistrict_GENERAL SERVICES DISTRICT  5879 non-null   bool
# ...

# %%
dataset['TaxDistrict_CITY OF GOODLETTSVILLE'] = dataset['TaxDistrict_CITY OF GOODLETTSVILLE'].astype(float)
dataset['TaxDistrict_GENERAL SERVICES DISTRICT'] = dataset['TaxDistrict_GENERAL SERVICES DISTRICT'].astype(float)
dataset['TaxDistrict_URBAN SERVICES DISTRICT'] = dataset['TaxDistrict_URBAN SERVICES DISTRICT'].astype(float)
dataset
# Out:
#       UniqueID   Acreage  LandValue  BuildingValue  TotalValue  Bedrooms  \
# 0          2045     2.30    50000.0       168200.0    235700.0       3.0
# 1         16918     3.50    50000.0       264100.0    319000.0       3.0
# 2         54582     2.90    50000.0       216200.0    298000.0       4.0
# 3         43070     2.60    50000.0       147300.0    197300.0       3.0
# 4         22714     2.00    50000.0       152300.0    202300.0       4.0
# ...         ...      ...        ...            ...         ...       ...
# 5874      39516     0.45    43000.0       157900.0    204700.0       2.0
# 5875      21382     0.46    38700.0       152400.0    191100.0       4.0
# 5876      31288     0.46    38700.0       129900.0    175600.0       2.0
# 5877       9854     0.22    30000.0       103500.0    133500.0       3.0
# 5878      12451     0.39    38700.0       184400.0    229000.0       3.0
#
#       FullBath  HalfBath  TaxDistrict_CITY OF GOODLETTSVILLE  \
# ...

# %%
dataset['TaxDistrict_CITY OF GOODLETTSVILLE'].value_counts()
# Out:
# TaxDistrict_CITY OF GOODLETTSVILLE
# 0.0    5500
# 1.0     379
# Name: count, dtype: int64

# %%
dataset['TaxDistrict_GENERAL SERVICES DISTRICT'].value_counts()
# Out:
# TaxDistrict_GENERAL SERVICES DISTRICT
# 0.0    3604
# 1.0    2275
# Name: count, dtype: int64

# %%
dataset['TaxDistrict_URBAN SERVICES DISTRICT'].value_counts()
# Out:
# TaxDistrict_URBAN SERVICES DISTRICT
# 0.0    4769
# 1.0    1110
# Name: count, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5879 entries, 0 to 5878
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   UniqueID                               5879 non-null   int64
#  1   Acreage                                5879 non-null   float64
#  2   LandValue                              5879 non-null   float64
#  3   BuildingValue                          5879 non-null   float64
#  4   TotalValue                             5879 non-null   float64
#  5   Bedrooms                               5879 non-null   float64
#  6   FullBath                               5879 non-null   float64
#  7   HalfBath                               5879 non-null   float64
#  8   TaxDistrict_CITY OF GOODLETTSVILLE     5879 non-null   float64
#  9   TaxDistrict_GENERAL SERVICES DISTRICT  5879 non-null   float64
# ...

# %%
df=dataset

# %%
X = df.drop('TotalValue',axis=1)
y = df['TotalValue']

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
# Creating the linear regressor
regressor_linear = LinearRegression()
regressor_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict:
y_pred = regressor_linear.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Calculamos el error cuadrático medio y el estadístico R^2
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
#print('RMSE: %.2f' % (mean_squared_error(y_test, y_pred,squared=False)))
print('MAE: %.2f' % mean_absolute_error(y_test, y_pred))
print('R_2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Error cuadrático medio: 18810108.69
# MAE: 1940.52
# R_2: 1.00

# %% [markdown]
# CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score
# crear el modelo
model = LinearRegression()
scores = cross_val_score(model, X, y, cv=5, verbose=1,scoring='r2') # cv= 5

# %%
print("%0.2f de r2 promedio con una desviación estandar de %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.99 de r2 promedio con una desviación estandar de 0.00
