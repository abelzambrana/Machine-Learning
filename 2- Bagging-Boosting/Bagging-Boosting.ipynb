# %%
# data science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# regression models
from sklearn.linear_model import LinearRegression # for linear regression

# %%
dataset = pd.read_csv('vivienda.csv')
dataset
# Out:
#       UniqueID   Acreage                TaxDistrict  LandValue  BuildingValue  \
# 0          2045     2.30  GENERAL SERVICES DISTRICT    50000.0       168200.0
# 1         16918     3.50  GENERAL SERVICES DISTRICT    50000.0       264100.0
# 2         54582     2.90  GENERAL SERVICES DISTRICT    50000.0       216200.0
# 3         43070     2.60  GENERAL SERVICES DISTRICT    50000.0       147300.0
# 4         22714     2.00  GENERAL SERVICES DISTRICT    50000.0       152300.0
# ...         ...      ...                        ...        ...            ...
# 5874      39516     0.45    URBAN SERVICES DISTRICT    43000.0       157900.0
# 5875      21382     0.46    URBAN SERVICES DISTRICT    38700.0       152400.0
# 5876      31288     0.46    URBAN SERVICES DISTRICT    38700.0       129900.0
# 5877       9854     0.22    URBAN SERVICES DISTRICT    30000.0       103500.0
# 5878      12451     0.39    URBAN SERVICES DISTRICT    38700.0       184400.0
#
#       TotalValue  Bedrooms  FullBath  HalfBath
# 0       235700.0       3.0       3.0       0.0
# 1       319000.0       3.0       3.0       2.0
# 2       298000.0       4.0       3.0       0.0
# 3       197300.0       3.0       3.0       0.0
# 4       202300.0       4.0       3.0       0.0
# ...          ...       ...       ...       ...
# 5874    204700.0       2.0       1.0       0.0
# 5875    191100.0       4.0       1.0       0.0
# 5876    175600.0       2.0       1.0       0.0
# 5877    133500.0       3.0       1.0       0.0
# 5878    229000.0       3.0       2.0       0.0
#
# [5879 rows x 9 columns]

# %%
dataset.isnull().sum()
# Out:
# UniqueID            0
# Acreage          2115
# TaxDistrict      2115
# LandValue        2115
# BuildingValue    2115
# TotalValue       2115
# Bedrooms         2336
# FullBath         2316
# HalfBath         2352
# dtype: int64

# %%
# Rellenamos con la Mediana, con una funcion anidada, le dice hace el calculo de la mediana y rellena
df = pd.get_dummies(dataset)
df=df.fillna(df.median())
df
# Out:
#       UniqueID   Acreage  LandValue  BuildingValue  TotalValue  Bedrooms  \
# 0          2045     2.30    50000.0       168200.0    235700.0       3.0
# 1         16918     3.50    50000.0       264100.0    319000.0       3.0
# 2         54582     2.90    50000.0       216200.0    298000.0       4.0
# 3         43070     2.60    50000.0       147300.0    197300.0       3.0
# 4         22714     2.00    50000.0       152300.0    202300.0       4.0
# ...         ...      ...        ...            ...         ...       ...
# 5874      39516     0.45    43000.0       157900.0    204700.0       2.0
# 5875      21382     0.46    38700.0       152400.0    191100.0       4.0
# 5876      31288     0.46    38700.0       129900.0    175600.0       2.0
# 5877       9854     0.22    30000.0       103500.0    133500.0       3.0
# 5878      12451     0.39    38700.0       184400.0    229000.0       3.0
#
#       FullBath  HalfBath  TaxDistrict_CITY OF GOODLETTSVILLE  \
# 0          3.0       0.0                               False
# 1          3.0       2.0                               False
# 2          3.0       0.0                               False
# 3          3.0       0.0                               False
# 4          3.0       0.0                               False
# ...        ...       ...                                 ...
# 5874       1.0       0.0                               False
# 5875       1.0       0.0                               False
# 5876       1.0       0.0                               False
# 5877       1.0       0.0                               False
# 5878       2.0       0.0                               False
#
#       TaxDistrict_GENERAL SERVICES DISTRICT  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
# ...                                     ...
# 5874                                  False
# 5875                                  False
# 5876                                  False
# 5877                                  False
# 5878                                  False
#
#       TaxDistrict_URBAN SERVICES DISTRICT
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 5874                                 True
# 5875                                 True
# 5876                                 True
# 5877                                 True
# 5878                                 True
#
# [5879 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# UniqueID                                 0
# Acreage                                  0
# LandValue                                0
# BuildingValue                            0
# TotalValue                               0
# Bedrooms                                 0
# FullBath                                 0
# HalfBath                                 0
# TaxDistrict_CITY OF GOODLETTSVILLE       0
# TaxDistrict_GENERAL SERVICES DISTRICT    0
# TaxDistrict_URBAN SERVICES DISTRICT      0
# dtype: int64

# %%
X = df.drop('TotalValue', axis = 1)
y = df['TotalValue']

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
print("Shape X_train: ",X_train.shape)
print("Shape X_test: ", X_test.shape)
print("Shape y_train: ",y_train.shape)
print("Shape y_test: ",y_test.shape)
# Out:
# Shape X_train:  (4703, 10)
# Shape X_test:  (1176, 10)
# Shape y_train:  (4703,)
# Shape y_test:  (1176,)

# %%
# Creating the linear regressor
regressor_linear = LinearRegression()
regressor_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict:
y_pred = regressor_linear.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# Calculamos el error cuadrático medio y el estadístico R^2
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
#print('RMSE: %.2f' % (mean_squared_error(y_test, y_pred, squared=False)))
print('MAE: %.2f' % mean_absolute_error(y_test, y_pred))
print('R_2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Error cuadrático medio: 18810108.69
# MAE: 1940.52
# R_2: 1.00

# %% [markdown]
# Con regresión lineal nos da R_2=1, esto implica eficiencia del 100% del modelo.

# %% [markdown]
# IMPLEMENTAREMOS ALGORITMOS DE ENSAMBLE BAGGING Y BOOSTING

# %% [markdown]
# Random Forest Regressor -- Bagging

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Instanciamos el modelo
rfr = RandomForestRegressor(n_estimators=25)

# %%
# Entrenamos:
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=25)

# %%
# Predicción
y_pred = rfr.predict(X_test)

# %%
# Calculamos el error cuadrático medio y el estadístico R^2
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
#print('RMSE: %.2f' % (mean_squared_error(y_test, y_pred, squared=False)))
print('MAE: %.2f' % mean_absolute_error(y_test, y_pred))
print('R_2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Error cuadrático medio: 173312491.52
# MAE: 2961.47
# R_2: 0.97

# %% [markdown]
# Ada Boost Regressor -- Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
abr = AdaBoostRegressor(n_estimators=25)

# %%
abr.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=25)

# %%
y_pred = abr.predict(X_test)

# %%
# Calculamos el error cuadrático medio y el estadístico R^2
print('Error cuadrático medio: %.2f' % mean_squared_error(y_test, y_pred))
#print('RMSE: %.2f' % (mean_squared_error(y_test, y_pred, squared=False)))
print('MAE: %.2f' % mean_absolute_error(y_test, y_pred))
print('R_2: %.2f' % r2_score(y_test, y_pred))
# Out:
# Error cuadrático medio: 455126301.18
# MAE: 12947.37
# R_2: 0.92

# %% [markdown]
# Conclusión: En este caso el boosting es menos eficiente que el bagging.
